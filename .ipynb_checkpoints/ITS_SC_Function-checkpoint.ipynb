# %%
#pip install opencv-python

# %%
import os
import re
import cv2 # opencv library
import numpy as np
from os.path import isfile, join
import matplotlib.pyplot as plt

# %%
col_frames = os.listdir('./Webcam Computer Vision/')
col_frames
# Out:
# ['camera0 (1).jpg',
#  'camera0 (2).jpg',
#  'camera0.jpg',
#  'GRCA webcam no vehicles 11282022.jpg',
#  'GRCA webcam work zone.jpg',
#  'Test_nocars.jpg',
#  'webcam_output_11142022.jpg',
#  'webcam_output_11212022.jpg',
#  'webcam_output_11212022_1.jpg']

# %%
col_images = []

# %%
for i in col_frames:
    # read the frames
    img = cv2.imread('./Webcam Computer Vision/'+i)
    # append the frames to the list
    col_images.append(img)

# %%
len(col_images)
# Out:
# 9

# %%
i = 0
for frame in range(i, len(col_images)-1):
    plt.imshow(cv2.cvtColor(col_images[frame], cv2.COLOR_BGR2RGB))
    plt.title("frame: "+str(frame))
    plt.show()

# %%
def vehicle_detection(image): 
    print("Base Image")
    plt.imshow(cv2.cvtColor(col_images[base_nocars], cv2.COLOR_BGR2RGB))
    plt.show()

    print("Image to Analyze")
    plt.imshow(cv2.cvtColor(col_images[to_analyze], cv2.COLOR_BGR2RGB))
    plt.show()

    grayA = cv2.cvtColor(col_images[3], cv2.COLOR_BGR2GRAY)
    grayB = cv2.cvtColor(col_images[to_analyze], cv2.COLOR_BGR2GRAY)


    print("Differencing")
    # plot the image after frame differencing
    plt.imshow(cv2.absdiff(grayB, grayA), cmap = 'gray')
    plt.show()

    diff_image = cv2.absdiff(grayB, grayA)

    # perform image thresholding
    ret, thresh = cv2.threshold(diff_image, 100, 255, cv2.THRESH_BINARY)

    cropped_image = thresh[230:1000,400:1200] # Slicing to crop the image

    # Display the cropped image
    print("Cropped:")
    plt.imshow(cropped_image, cmap = 'gray')
    plt.show()

    # apply image dilation
    kernel = np.ones((3,3),np.uint8)
    kernel

    dilated = cv2.dilate(cropped_image,kernel,iterations = 4)

    # original image
    # -1 loads as-is so if it will be 3 or 4 channel as the original
    image = cropped_image
    # mask defaulting to black for 3-channel and transparent for 4-channel

    #https://stackoverflow.com/questions/15341538/numpy-opencv-2-how-do-i-crop-non-rectangular-region
    mask = np.zeros(image.shape, dtype=np.uint8)
    roi_corners = np.array([[(0,0),(0,180), (180,150), (400,700),(800,700),(800,600),(400,100),(500,100),(800,250),(800,150),(350,0)]], dtype=np.int32)
    # fill the ROI so it doesn't get wiped out when the mask is applied

    #channel_count
    ignore_mask_color = (255,) #*channel_count
    cv2.fillPoly(mask, roi_corners, ignore_mask_color)

    # apply the mask
    masked_image = cv2.bitwise_and(image, mask)

    print("Masked:")
    #plt.masked_image
    plt.imshow(cv2.cvtColor(masked_image, cv2.COLOR_BGR2RGB))
    plt.show()

    contours, hierarchy = cv2.findContours(masked_image.copy(),cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)

    valid_cntrs = []

    for i,cntr in enumerate(contours):
        x,y,w,h = cv2.boundingRect(cntr)
        #if (x <= 200) & (y >= 80) & (cv2.contourArea(cntr) >= 25):
        # If contr length is above X, add append it
        valid_cntrs.append(cntr)

    # count of discovered contours        

    dmy = col_images[to_analyze].copy()
    dmy = dmy[230:1000,400:1200]

    print("Contours Drawn:")
    cv2.drawContours(dmy, valid_cntrs, -1, (127,200,0), 2)
    cv2.line(dmy, (0, 200),(1200,200),(100, 255, 255))
    plt.imshow(dmy)
    plt.show()


    print("Number of Contours: ", len(valid_cntrs))
    if len(valid_cntrs) >300:
        print("Above threshold, vehicles present")
    else: 
        print("Not above threshold. No Vehicle.")
        
    all_contours = np.concatenate(valid_cntrs, axis=0)
    try:
        print(all_contours[all_contours.argmin(axis = 0)])
# Out:
#   Input In [154]
#     print(all_contours[all_contours.argmin(axis = 0)])
#                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
# convert the frames to grayscale
to_analyze = 3
base_nocars = 3
vehicle_detection(to_analyze)
# Out:
# Base Image
# Image to Analyze
# Differencing
# Cropped:
# Masked:
# Contours Drawn:
# Number of Contours:  0
# Not above threshold. No Vehicle.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [152], in <cell line: 4>()
#       2 to_analyze = 3
#       3 base_nocars = 3
# ----> 4 vehicle_detection(to_analyze)
#
# Input In [151], in vehicle_detection(image)
#      84 else:
#      85     print("Not above threshold. No Vehicle.")
# ---> 87 all_contours = np.concatenate(valid_cntrs, axis=0)
#      88 print(all_contours[all_contours.argmin(axis = 0)])
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# ValueError: need at least one array to concatenate

# %%
test = 10
print(type(valid_cntrs[test]))
all_contours = np.concatenate(valid_cntrs, axis=0)
print(all_contours[all_contours.argmin(axis = 0)])
#print(valid_cntrs.argmin())
# Out:
# <class 'numpy.ndarray'>
# [[[[  0 165]]
#
#   [[296   0]]]]

# %%
# Out:
# 2

# %%
valid_cntrs
# Out:
# [array([[[485, 698]],
#
#         [[484, 699]],
#
#         [[485, 699]],
#
#         [[486, 698]],
#
#         [[487, 698]],
#
#         [[486, 698]]], dtype=int32),
#  array([[[509, 691]],
#
#         [[510, 691]]], dtype=int32),
#  array([[[680, 689]]], dtype=int32),
#  array([[[677, 686]],
#
#         [[678, 686]],
#
#         [[679, 686]],
#
#         [[678, 686]]], dtype=int32),
#  array([[[607, 683]],
#
#         [[606, 684]],
#
#         [[607, 684]],
#
#         [[608, 684]],
#
#         [[609, 684]],
#
#         [[608, 684]]], dtype=int32),
#  array([[[628, 682]],
#
#         [[629, 683]],
#
#         [[629, 684]],
#
#         [[629, 685]],
#
#         [[630, 686]],
#
#         [[631, 686]],
#
#         [[631, 685]],
#
#         [[631, 684]],
#
#         [[631, 683]],
#
#         [[630, 682]],
#
#         [[629, 682]]], dtype=int32),
#  array([[[550, 682]],
#
#         [[551, 682]]], dtype=int32),
#  array([[[661, 681]]], dtype=int32),
#  array([[[511, 680]]], dtype=int32),
#  array([[[687, 675]],
#
#         [[687, 676]]], dtype=int32),
#  array([[[400, 675]]], dtype=int32),
#  array([[[784, 674]],
#
#         [[785, 674]],
#
#         [[786, 674]],
#
#         [[787, 674]],
#
#         [[788, 674]],
#
#         [[789, 674]],
#
#         [[790, 674]],
#
#         [[791, 674]],
#
#         [[790, 674]],
#
#         [[789, 674]],
#
#         [[788, 674]],
#
#         [[787, 674]],
#
#         [[786, 674]],
#
#         [[785, 674]]], dtype=int32),
#  array([[[673, 674]],
#
#         [[672, 675]],
#
#         [[672, 676]],
#
#         [[671, 677]],
#
#         [[670, 677]],
#
#         [[669, 678]],
#
#         [[668, 678]],
#
#         [[667, 679]],
#
#         [[666, 679]],
#
#         [[665, 679]],
#
#         [[664, 679]],
#
#         [[663, 680]],
#
#         [[664, 680]],
#
#         [[665, 680]],
#
#         [[666, 680]],
#
#         [[667, 680]],
#
#         [[668, 680]],
#
#         [[669, 680]],
#
#         [[670, 679]],
#
#         [[671, 679]],
#
#         [[672, 679]],
#
#         [[673, 679]],
#
#         [[674, 679]],
#
#         [[675, 679]],
#
#         [[676, 679]],
#
#         [[677, 678]],
#
#         [[677, 677]],
#
#         [[676, 676]],
#
#         [[675, 675]],
#
#         [[674, 675]]], dtype=int32),
#  array([[[511, 674]],
#
#         [[511, 675]]], dtype=int32),
#  array([[[415, 674]]], dtype=int32),
#  array([[[531, 673]]], dtype=int32),
#  array([[[502, 673]],
#
#         [[503, 673]]], dtype=int32),
#  array([[[534, 671]]], dtype=int32),
#  array([[[691, 669]],
#
#         [[690, 670]],
#
#         [[691, 671]],
#
#         [[692, 670]]], dtype=int32),
#  array([[[791, 668]]], dtype=int32),
#  array([[[784, 668]]], dtype=int32),
#  array([[[787, 666]],
#
#         [[788, 666]]], dtype=int32),
#  array([[[779, 666]],
#
#         [[780, 666]],
#
#         [[781, 666]],
#
#         [[782, 666]],
#
#         [[783, 666]],
#
#         [[782, 666]],
#
#         [[781, 666]],
#
#         [[780, 666]]], dtype=int32),
#  array([[[412, 666]],
#
#         [[413, 667]],
#
#         [[413, 666]]], dtype=int32),
#  array([[[703, 664]],
#
#         [[702, 665]],
#
#         [[701, 666]],
#
#         [[700, 666]],
#
#         [[699, 666]],
#
#         [[698, 665]],
#
#         [[697, 666]],
#
#         [[696, 666]],
#
#         [[696, 667]],
#
#         [[695, 668]],
#
#         [[695, 669]],
#
#         [[694, 670]],
#
#         [[694, 671]],
#
#         [[694, 672]],
#
#         [[695, 672]],
#
#         [[696, 673]],
#
#         [[697, 673]],
#
#         [[698, 673]],
#
#         [[699, 674]],
#
#         [[699, 675]],
#
#         [[699, 676]],
#
#         [[699, 677]],
#
#         [[699, 678]],
#
#         [[699, 679]],
#
#         [[699, 680]],
#
#         [[699, 681]],
#
#         [[698, 682]],
#
#         [[697, 682]],
#
#         [[696, 682]],
#
#         [[695, 681]],
#
#         [[695, 680]],
#
#         [[695, 679]],
#
#         [[695, 678]],
#
#         [[694, 677]],
#
#         [[693, 677]],
#
#         [[692, 676]],
#
#         [[692, 675]],
#
#         [[692, 674]],
#
#         [[691, 675]],
#
#         [[690, 676]],
#
#         [[689, 677]],
#
#         [[688, 678]],
#
#         [[687, 678]],
#
#         [[686, 678]],
#
#         [[686, 679]],
#
#         [[687, 680]],
#
#         [[686, 681]],
#
#         [[685, 681]],
#
#         [[685, 682]],
#
#         [[685, 683]],
#
#         [[685, 684]],
#
#         [[685, 685]],
#
#         [[685, 686]],
#
#         [[686, 687]],
#
#         [[687, 687]],
#
#         [[688, 688]],
#
#         [[688, 689]],
#
#         [[689, 689]],
#
#         [[690, 689]],
#
#         [[691, 688]],
#
#         [[692, 688]],
#
#         [[693, 687]],
#
#         [[694, 687]],
#
#         [[695, 687]],
#
#         [[695, 686]],
#
#         [[695, 685]],
#
#         [[696, 684]],
#
#         [[697, 684]],
#
#         [[698, 683]],
#
#         [[698, 682]],
#
#         [[699, 681]],
#
#         [[699, 680]],
#
#         [[699, 679]],
#
#         [[699, 678]],
#
#         [[699, 677]],
#
#         [[699, 676]],
#
#         [[699, 675]],
#
#         [[699, 674]],
#
#         [[700, 673]],
#
#         [[701, 673]],
#
#         [[702, 673]],
#
#         [[703, 673]],
#
#         [[703, 672]],
#
#         [[703, 671]],
#
#         [[703, 670]],
#
#         [[703, 669]],
#
#         [[703, 668]],
#
#         [[703, 667]],
#
#         [[703, 666]],
#
#         [[703, 665]]], dtype=int32),
#  array([[[512, 664]],
#
#         [[512, 665]],
#
#         [[511, 666]],
#
#         [[510, 666]],
#
#         [[509, 666]],
#
#         [[508, 666]],
#
#         [[507, 666]],
#
#         [[508, 667]],
#
#         [[509, 668]],
#
#         [[510, 668]],
#
#         [[511, 668]],
#
#         [[512, 669]],
#
#         [[513, 669]],
#
#         [[514, 669]],
#
#         [[515, 668]],
#
#         [[515, 667]],
#
#         [[515, 666]],
#
#         [[514, 665]],
#
#         [[513, 664]]], dtype=int32),
#  array([[[618, 662]],
#
#         [[619, 663]],
#
#         [[620, 662]],
#
#         [[619, 662]]], dtype=int32),
#  array([[[726, 661]],
#
#         [[727, 662]],
#
#         [[727, 661]]], dtype=int32),
#  array([[[504, 660]],
#
#         [[504, 661]],
#
#         [[503, 662]],
#
#         [[502, 661]],
#
#         [[501, 661]],
#
#         [[500, 661]],
#
#         [[499, 661]],
#
#         [[500, 662]],
#
#         [[501, 662]],
#
#         [[502, 662]],
#
#         [[503, 662]],
#
#         [[504, 661]],
#
#         [[505, 661]],
#
#         [[506, 661]],
#
#         [[506, 660]],
#
#         [[505, 660]]], dtype=int32),
#  array([[[488, 660]],
#
#         [[488, 661]]], dtype=int32),
#  array([[[540, 658]],
#
#         [[541, 659]],
#
#         [[542, 658]],
#
#         [[541, 658]]], dtype=int32),
#  array([[[523, 658]],
#
#         [[523, 659]],
#
#         [[524, 659]],
#
#         [[525, 659]],
#
#         [[525, 658]],
#
#         [[524, 658]]], dtype=int32),
#  array([[[510, 658]],
#
#         [[510, 659]],
#
#         [[509, 660]],
#
#         [[510, 660]],
#
#         [[511, 660]],
#
#         [[511, 659]],
#
#         [[511, 658]]], dtype=int32),
#  array([[[500, 658]],
#
#         [[501, 658]],
#
#         [[502, 658]],
#
#         [[503, 658]],
#
#         [[502, 658]],
#
#         [[501, 658]]], dtype=int32),
#  array([[[455, 658]],
#
#         [[455, 659]],
#
#         [[455, 660]],
#
#         [[455, 659]]], dtype=int32),
#  array([[[571, 657]],
#
#         [[572, 657]]], dtype=int32),
#  array([[[784, 656]],
#
#         [[784, 657]],
#
#         [[785, 657]],
#
#         [[786, 657]],
#
#         [[786, 656]],
#
#         [[785, 656]]], dtype=int32),
#  array([[[793, 654]],
#
#         [[792, 655]],
#
#         [[793, 656]],
#
#         [[794, 656]],
#
#         [[795, 656]],
#
#         [[796, 655]],
#
#         [[797, 655]],
#
#         [[798, 656]],
#
#         [[799, 657]],
#
#         [[798, 658]],
#
#         [[797, 658]],
#
#         [[796, 658]],
#
#         [[795, 658]],
#
#         [[794, 658]],
#
#         [[794, 659]],
#
#         [[793, 660]],
#
#         [[792, 661]],
#
#         [[792, 662]],
#
#         [[792, 663]],
#
#         [[792, 664]],
#
#         [[792, 665]],
#
#         [[793, 664]],
#
#         [[794, 664]],
#
#         [[795, 664]],
#
#         [[796, 665]],
#
#         [[795, 666]],
#
#         [[795, 667]],
#
#         [[796, 668]],
#
#         [[797, 668]],
#
#         [[798, 669]],
#
#         [[799, 669]],
#
#         [[799, 668]],
#
#         [[799, 667]],
#
#         [[799, 666]],
#
#         [[799, 665]],
#
#         [[799, 664]],
#
#         [[799, 663]],
#
#         [[799, 662]],
#
#         [[799, 661]],
#
#         [[799, 660]],
#
#         [[799, 659]],
#
#         [[799, 658]],
#
#         [[799, 657]],
#
#         [[799, 656]],
#
#         [[799, 655]],
#
#         [[799, 654]],
#
#         [[798, 654]],
#
#         [[797, 654]],
#
#         [[796, 654]],
#
#         [[795, 654]],
#
#         [[794, 654]]], dtype=int32),
#  array([[[734, 650]]], dtype=int32),
#  array([[[728, 650]],
#
#         [[729, 650]],
#
#         [[730, 650]],
#
#         [[729, 650]]], dtype=int32),
#  array([[[699, 650]]], dtype=int32),
#  array([[[506, 648]],
#
#         [[505, 649]],
#
#         [[504, 649]],
#
#         [[505, 649]],
#
#         [[506, 649]],
#
#         [[507, 649]],
#
#         [[508, 649]],
#
#         [[507, 649]]], dtype=int32),
#  array([[[485, 647]],
#
#         [[486, 648]],
#
#         [[486, 647]]], dtype=int32),
#  array([[[481, 646]]], dtype=int32),
#  array([[[775, 645]]], dtype=int32),
#  array([[[512, 645]],
#
#         [[512, 646]],
#
#         [[512, 647]],
#
#         [[512, 646]]], dtype=int32),
#  array([[[459, 644]],
#
#         [[458, 645]],
#
#         [[457, 645]],
#
#         [[456, 645]],
#
#         [[457, 646]],
#
#         [[456, 647]],
#
#         [[455, 647]],
#
#         [[454, 647]],
#
#         [[455, 648]],
#
#         [[456, 647]],
#
#         [[457, 648]],
#
#         [[458, 649]],
#
#         [[459, 650]],
#
#         [[460, 651]],
#
#         [[461, 650]],
#
#         [[462, 649]],
#
#         [[463, 649]],
#
#         [[462, 649]],
#
#         [[461, 649]],
#
#         [[460, 648]],
#
#         [[459, 647]],
#
#         [[459, 646]],
#
#         [[460, 645]],
#
#         [[461, 645]],
#
#         [[462, 645]],
#
#         [[463, 645]],
#
#         [[463, 644]],
#
#         [[462, 644]],
#
#         [[461, 644]],
#
#         [[460, 645]]], dtype=int32),
#  array([[[768, 642]]], dtype=int32),
#  array([[[396, 642]],
#
#         [[397, 642]]], dtype=int32),
#  array([[[441, 641]],
#
#         [[442, 641]]], dtype=int32),
#  array([[[394, 639]]], dtype=int32),
#  array([[[750, 635]],
#
#         [[750, 636]],
#
#         [[750, 637]],
#
#         [[751, 637]],
#
#         [[751, 636]],
#
#         [[751, 635]]], dtype=int32),
#  array([[[744, 634]],
#
#         [[745, 634]]], dtype=int32),
#  array([[[736, 634]],
#
#         [[736, 635]],
#
#         [[737, 635]],
#
#         [[738, 635]],
#
#         [[739, 634]],
#
#         [[740, 634]],
#
#         [[741, 634]],
#
#         [[740, 634]],
#
#         [[739, 634]],
#
#         [[738, 634]],
#
#         [[737, 634]]], dtype=int32),
#  array([[[712, 634]]], dtype=int32),
#  array([[[526, 634]]], dtype=int32),
#  array([[[552, 632]],
#
#         [[552, 633]],
#
#         [[551, 634]],
#
#         [[550, 634]],
#
#         [[549, 634]],
#
#         [[548, 634]],
#
#         [[547, 633]],
#
#         [[546, 633]],
#
#         [[545, 633]],
#
#         [[544, 633]],
#
#         [[544, 634]],
#
#         [[543, 635]],
#
#         [[544, 634]],
#
#         [[545, 634]],
#
#         [[546, 634]],
#
#         [[547, 634]],
#
#         [[548, 634]],
#
#         [[549, 634]],
#
#         [[550, 634]],
#
#         [[551, 634]],
#
#         [[552, 634]],
#
#         [[553, 633]]], dtype=int32),
#  array([[[764, 631]],
#
#         [[764, 632]],
#
#         [[764, 633]],
#
#         [[765, 633]],
#
#         [[765, 632]],
#
#         [[765, 631]]], dtype=int32),
#  array([[[704, 630]],
#
#         [[703, 631]],
#
#         [[702, 632]],
#
#         [[703, 632]],
#
#         [[704, 631]]], dtype=int32),
#  array([[[528, 630]]], dtype=int32),
#  array([[[533, 628]],
#
#         [[534, 628]],
#
#         [[535, 628]],
#
#         [[536, 629]],
#
#         [[537, 629]],
#
#         [[538, 629]],
#
#         [[539, 629]],
#
#         [[540, 629]],
#
#         [[541, 629]],
#
#         [[542, 629]],
#
#         [[543, 629]],
#
#         [[544, 629]],
#
#         [[545, 629]],
#
#         [[546, 629]],
#
#         [[547, 629]],
#
#         [[546, 629]],
#
#         [[545, 629]],
#
#         [[544, 629]],
#
#         [[543, 628]],
#
#         [[542, 628]],
#
#         [[541, 628]],
#
#         [[540, 628]],
#
#         [[539, 628]],
#
#         [[538, 628]],
#
#         [[537, 629]],
#
#         [[536, 629]],
#
#         [[535, 628]],
#
#         [[534, 628]]], dtype=int32),
#  array([[[512, 628]],
#
#         [[512, 629]],
#
#         [[513, 629]],
#
#         [[514, 629]],
#
#         [[515, 630]],
#
#         [[516, 630]],
#
#         [[517, 630]],
#
#         [[518, 629]],
#
#         [[519, 629]],
#
#         [[518, 629]],
#
#         [[517, 628]],
#
#         [[516, 628]],
#
#         [[515, 628]],
#
#         [[514, 628]],
#
#         [[513, 628]]], dtype=int32),
#  array([[[706, 627]]], dtype=int32),
#  array([[[719, 626]]], dtype=int32),
#  array([[[451, 626]],
#
#         [[451, 627]],
#
#         [[451, 628]],
#
#         [[451, 629]],
#
#         [[451, 630]],
#
#         [[451, 631]],
#
#         [[451, 632]],
#
#         [[451, 633]],
#
#         [[450, 634]],
#
#         [[449, 634]],
#
#         [[448, 634]],
#
#         [[447, 633]],
#
#         [[447, 632]],
#
#         [[447, 633]],
#
#         [[448, 634]],
#
#         [[447, 635]],
#
#         [[448, 636]],
#
#         [[448, 637]],
#
#         [[448, 638]],
#
#         [[449, 638]],
#
#         [[450, 638]],
#
#         [[451, 638]],
#
#         [[452, 638]],
#
#         [[451, 637]],
#
#         [[452, 636]],
#
#         [[453, 636]],
#
#         [[454, 636]],
#
#         [[455, 636]],
#
#         [[455, 635]],
#
#         [[456, 634]],
#
#         [[457, 634]],
#
#         [[456, 634]],
#
#         [[455, 635]],
#
#         [[454, 635]],
#
#         [[453, 634]],
#
#         [[454, 633]],
#
#         [[454, 632]],
#
#         [[453, 631]],
#
#         [[453, 630]],
#
#         [[453, 629]],
#
#         [[453, 628]],
#
#         [[453, 627]],
#
#         [[453, 626]],
#
#         [[452, 626]]], dtype=int32),
#  array([[[701, 625]]], dtype=int32),
#  array([[[560, 625]]], dtype=int32),
#  array([[[510, 625]],
#
#         [[510, 626]],
#
#         [[511, 626]],
#
#         [[512, 625]],
#
#         [[513, 625]],
#
#         [[512, 625]],
#
#         [[511, 625]]], dtype=int32),
#  array([[[708, 624]],
#
#         [[708, 625]]], dtype=int32),
#  array([[[525, 623]],
#
#         [[525, 624]],
#
#         [[526, 624]],
#
#         [[526, 623]]], dtype=int32),
#  array([[[518, 623]],
#
#         [[519, 623]]], dtype=int32),
#  array([[[444, 623]]], dtype=int32),
#  array([[[389, 623]]], dtype=int32),
#  array([[[380, 623]]], dtype=int32),
#  array([[[760, 622]],
#
#         [[760, 623]],
#
#         [[760, 624]],
#
#         [[760, 625]],
#
#         [[759, 626]],
#
#         [[758, 626]],
#
#         [[759, 626]],
#
#         [[760, 627]],
#
#         [[760, 628]],
#
#         [[760, 629]],
#
#         [[760, 628]],
#
#         [[760, 627]],
#
#         [[760, 626]],
#
#         [[761, 625]],
#
#         [[762, 625]],
#
#         [[761, 624]],
#
#         [[761, 623]]], dtype=int32),
#  array([[[541, 622]],
#
#         [[541, 623]],
#
#         [[542, 623]],
#
#         [[543, 623]],
#
#         [[543, 622]],
#
#         [[542, 622]]], dtype=int32),
#  array([[[712, 620]],
#
#         [[711, 621]],
#
#         [[710, 621]],
#
#         [[711, 621]]], dtype=int32),
#  array([[[464, 620]]], dtype=int32),
#  array([[[524, 618]],
#
#         [[523, 619]],
#
#         [[524, 620]],
#
#         [[525, 620]],
#
#         [[525, 619]]], dtype=int32),
#  array([[[519, 618]]], dtype=int32),
#  array([[[385, 618]]], dtype=int32),
#  array([[[487, 617]],
#
#         [[488, 617]]], dtype=int32),
#  array([[[701, 616]],
#
#         [[701, 617]],
#
#         [[702, 617]],
#
#         [[703, 617]],
#
#         [[704, 618]],
#
#         [[703, 619]],
#
#         [[702, 619]],
#
#         [[701, 619]],
#
#         [[701, 620]],
#
#         [[700, 621]],
#
#         [[699, 622]],
#
#         [[698, 621]],
#
#         [[697, 620]],
#
#         [[696, 620]],
#
#         [[696, 621]],
#
#         [[697, 621]],
#
#         [[698, 622]],
#
#         [[699, 622]],
#
#         [[700, 623]],
#
#         [[701, 623]],
#
#         [[702, 623]],
#
#         [[703, 622]],
#
#         [[704, 622]],
#
#         [[703, 621]],
#
#         [[703, 620]],
#
#         [[703, 619]],
#
#         [[704, 618]],
#
#         [[704, 617]],
#
#         [[703, 616]],
#
#         [[702, 616]]], dtype=int32),
#  array([[[463, 616]],
#
#         [[462, 617]],
#
#         [[463, 617]]], dtype=int32),
#  array([[[446, 616]],
#
#         [[445, 617]],
#
#         [[444, 618]],
#
#         [[443, 618]],
#
#         [[442, 618]],
#
#         [[443, 618]],
#
#         [[444, 618]],
#
#         [[445, 618]],
#
#         [[446, 619]],
#
#         [[447, 620]],
#
#         [[448, 621]],
#
#         [[448, 622]],
#
#         [[448, 623]],
#
#         [[448, 624]],
#
#         [[447, 625]],
#
#         [[446, 624]],
#
#         [[445, 625]],
#
#         [[446, 625]],
#
#         [[447, 625]],
#
#         [[448, 624]],
#
#         [[449, 624]],
#
#         [[450, 623]],
#
#         [[451, 623]],
#
#         [[452, 622]],
#
#         [[453, 622]],
#
#         [[454, 621]],
#
#         [[455, 621]],
#
#         [[456, 622]],
#
#         [[457, 621]],
#
#         [[458, 620]],
#
#         [[457, 620]],
#
#         [[456, 620]],
#
#         [[455, 619]],
#
#         [[455, 618]],
#
#         [[456, 617]],
#
#         [[457, 617]],
#
#         [[456, 617]],
#
#         [[455, 616]],
#
#         [[454, 616]],
#
#         [[453, 616]],
#
#         [[453, 617]],
#
#         [[452, 618]],
#
#         [[451, 618]],
#
#         [[450, 618]],
#
#         [[449, 617]],
#
#         [[448, 617]],
#
#         [[447, 616]]], dtype=int32),
#  array([[[446, 618]],
#
#         [[447, 617]],
#
#         [[448, 618]],
#
#         [[447, 619]]], dtype=int32),
#  array([[[496, 615]]], dtype=int32),
#  array([[[753, 614]]], dtype=int32),
#  array([[[728, 614]]], dtype=int32),
#  array([[[507, 614]],
#
#         [[506, 615]],
#
#         [[506, 616]],
#
#         [[507, 617]],
#
#         [[508, 617]],
#
#         [[509, 617]],
#
#         [[510, 617]],
#
#         [[511, 617]],
#
#         [[510, 617]],
#
#         [[509, 616]],
#
#         [[508, 615]],
#
#         [[508, 614]]], dtype=int32),
#  array([[[528, 613]]], dtype=int32),
#  array([[[521, 613]],
#
#         [[520, 614]],
#
#         [[520, 615]],
#
#         [[520, 616]],
#
#         [[521, 616]],
#
#         [[522, 615]],
#
#         [[523, 615]],
#
#         [[524, 615]],
#
#         [[525, 615]],
#
#         [[525, 614]],
#
#         [[524, 613]],
#
#         [[523, 613]],
#
#         [[522, 613]]], dtype=int32),
#  array([[[372, 613]]], dtype=int32),
#  array([[[753, 612]],
#
#         [[754, 612]]], dtype=int32),
#  array([[[511, 611]],
#
#         [[511, 612]]], dtype=int32),
#  array([[[400, 610]],
#
#         [[401, 610]]], dtype=int32),
#  array([[[744, 608]],
#
#         [[744, 609]]], dtype=int32),
#  array([[[704, 608]],
#
#         [[703, 609]],
#
#         [[702, 610]],
#
#         [[701, 610]],
#
#         [[700, 610]],
#
#         [[699, 610]],
#
#         [[700, 611]],
#
#         [[701, 611]],
#
#         [[702, 611]],
#
#         [[703, 611]],
#
#         [[704, 610]],
#
#         [[705, 611]],
#
#         [[705, 612]],
#
#         [[705, 613]],
#
#         [[706, 613]],
#
#         [[705, 612]],
#
#         [[705, 611]],
#
#         [[705, 610]],
#
#         [[705, 609]],
#
#         [[705, 608]]], dtype=int32),
#  array([[[748, 607]],
#
#         [[747, 608]],
#
#         [[747, 609]],
#
#         [[746, 610]],
#
#         [[745, 611]],
#
#         [[744, 612]],
#
#         [[744, 613]],
#
#         [[744, 614]],
#
#         [[744, 615]],
#
#         [[745, 616]],
#
#         [[746, 617]],
#
#         [[747, 617]],
#
#         [[748, 617]],
#
#         [[749, 618]],
#
#         [[749, 619]],
#
#         [[749, 620]],
#
#         [[749, 621]],
#
#         [[749, 622]],
#
#         [[749, 623]],
#
#         [[749, 624]],
#
#         [[749, 625]],
#
#         [[750, 626]],
#
#         [[750, 627]],
#
#         [[750, 628]],
#
#         [[750, 629]],
#
#         [[750, 630]],
#
#         [[750, 631]],
#
#         [[750, 632]],
#
#         [[750, 633]],
#
#         [[751, 633]],
#
#         [[751, 632]],
#
#         [[751, 631]],
#
#         [[751, 630]],
#
#         [[751, 629]],
#
#         [[751, 628]],
#
#         [[751, 627]],
#
#         [[751, 626]],
#
#         [[751, 625]],
#
#         [[751, 624]],
#
#         [[751, 623]],
#
#         [[751, 622]],
#
#         [[752, 621]],
#
#         [[753, 621]],
#
#         [[754, 621]],
#
#         [[755, 620]],
#
#         [[755, 619]],
#
#         [[755, 618]],
#
#         [[754, 618]],
#
#         [[753, 617]],
#
#         [[754, 616]],
#
#         [[753, 616]],
#
#         [[752, 616]],
#
#         [[751, 615]],
#
#         [[751, 614]],
#
#         [[751, 613]],
#
#         [[751, 612]],
#
#         [[750, 611]],
#
#         [[749, 610]],
#
#         [[748, 609]],
#
#         [[748, 608]]], dtype=int32),
#  array([[[750, 616]],
#
#         [[751, 615]],
#
#         [[752, 616]],
#
#         [[752, 617]],
#
#         [[751, 618]],
#
#         [[750, 618]],
#
#         [[749, 617]]], dtype=int32),
#  array([[[695, 606]],
#
#         [[695, 607]],
#
#         [[695, 608]],
#
#         [[696, 607]]], dtype=int32),
#  array([[[690, 606]],
#
#         [[689, 607]],
#
#         [[688, 607]],
#
#         [[688, 608]],
#
#         [[688, 609]],
#
#         [[689, 610]],
#
#         [[689, 611]],
#
#         [[690, 612]],
#
#         [[691, 612]],
#
#         [[692, 613]],
#
#         [[692, 614]],
#
#         [[692, 615]],
#
#         [[693, 616]],
#
#         [[694, 616]],
#
#         [[695, 617]],
#
#         [[695, 616]],
#
#         [[695, 615]],
#
#         [[695, 614]],
#
#         [[695, 613]],
#
#         [[695, 612]],
#
#         [[695, 611]],
#
#         [[695, 610]],
#
#         [[694, 610]],
#
#         [[693, 609]],
#
#         [[693, 608]],
#
#         [[692, 608]],
#
#         [[691, 607]]], dtype=int32),
#  array([[[752, 605]],
#
#         [[752, 606]],
#
#         [[751, 607]],
#
#         [[751, 608]],
#
#         [[751, 609]],
#
#         [[751, 608]],
#
#         [[751, 607]],
#
#         [[752, 606]],
#
#         [[753, 607]],
#
#         [[754, 608]],
#
#         [[754, 609]],
#
#         [[754, 608]],
#
#         [[753, 607]],
#
#         [[753, 606]]], dtype=int32),
#  array([[[692, 604]]], dtype=int32),
#  array([[[587, 604]],
#
#         [[588, 604]],
#
#         [[589, 604]],
#
#         [[590, 604]],
#
#         [[591, 604]],
#
#         [[590, 604]],
#
#         [[589, 604]],
#
#         [[588, 604]]], dtype=int32),
#  array([[[749, 602]],
#
#         [[749, 603]]], dtype=int32),
#  array([[[704, 600]],
#
#         [[704, 601]],
#
#         [[705, 600]],
#
#         [[706, 600]],
#
#         [[707, 600]],
#
#         [[708, 601]],
#
#         [[709, 601]],
#
#         [[710, 602]],
#
#         [[709, 603]],
#
#         [[710, 604]],
#
#         [[710, 603]],
#
#         [[711, 602]],
#
#         [[710, 602]],
#
#         [[709, 601]],
#
#         [[708, 600]],
#
#         [[707, 600]],
#
#         [[706, 600]],
#
#         [[705, 600]]], dtype=int32),
#  array([[[746, 599]],
#
#         [[746, 600]],
#
#         [[746, 601]],
#
#         [[747, 601]],
#
#         [[747, 600]]], dtype=int32),
#  array([[[442, 598]],
#
#         [[442, 599]],
#
#         [[441, 600]],
#
#         [[440, 601]],
#
#         [[441, 601]],
#
#         [[442, 601]],
#
#         [[443, 601]],
#
#         [[443, 600]],
#
#         [[443, 599]]], dtype=int32),
#  array([[[695, 597]],
#
#         [[695, 598]],
#
#         [[695, 599]],
#
#         [[695, 600]],
#
#         [[695, 601]],
#
#         [[695, 602]],
#
#         [[696, 601]],
#
#         [[697, 601]],
#
#         [[698, 602]],
#
#         [[699, 602]],
#
#         [[700, 602]],
#
#         [[699, 602]],
#
#         [[698, 601]],
#
#         [[697, 600]],
#
#         [[696, 599]],
#
#         [[695, 598]]], dtype=int32),
#  array([[[752, 594]],
#
#         [[753, 594]]], dtype=int32),
#  array([[[535, 594]]], dtype=int32),
#  array([[[442, 594]],
#
#         [[442, 595]],
#
#         [[443, 595]],
#
#         [[443, 594]]], dtype=int32),
#  array([[[700, 593]],
#
#         [[699, 594]],
#
#         [[700, 594]]], dtype=int32),
#  array([[[681, 592]],
#
#         [[680, 593]],
#
#         [[679, 594]],
#
#         [[678, 594]],
#
#         [[678, 595]],
#
#         [[679, 596]],
#
#         [[679, 597]],
#
#         [[680, 596]],
#
#         [[681, 596]],
#
#         [[682, 597]],
#
#         [[683, 596]],
#
#         [[684, 596]],
#
#         [[685, 597]],
#
#         [[686, 597]],
#
#         [[685, 597]],
#
#         [[684, 596]],
#
#         [[683, 595]],
#
#         [[683, 594]],
#
#         [[683, 593]],
#
#         [[682, 592]]], dtype=int32),
#  array([[[544, 592]],
#
#         [[544, 593]],
#
#         [[544, 594]],
#
#         [[545, 594]],
#
#         [[545, 593]]], dtype=int32),
#  array([[[688, 591]],
#
#         [[687, 592]],
#
#         [[687, 593]],
#
#         [[688, 593]],
#
#         [[689, 593]],
#
#         [[690, 593]],
#
#         [[691, 594]],
#
#         [[692, 595]],
#
#         [[693, 594]],
#
#         [[692, 593]],
#
#         [[692, 592]],
#
#         [[691, 591]],
#
#         [[690, 591]],
#
#         [[689, 591]]], dtype=int32),
#  array([[[376, 590]],
#
#         [[377, 590]]], dtype=int32),
#  array([[[705, 589]],
#
#         [[705, 590]],
#
#         [[706, 590]]], dtype=int32),
#  array([[[448, 589]]], dtype=int32),
#  array([[[436, 588]],
#
#         [[436, 589]],
#
#         [[437, 590]],
#
#         [[437, 591]],
#
#         [[438, 591]],
#
#         [[438, 590]],
#
#         [[438, 589]],
#
#         [[437, 588]]], dtype=int32),
#  array([[[444, 587]]], dtype=int32),
#  array([[[440, 587]],
#
#         [[441, 587]],
#
#         [[442, 587]],
#
#         [[441, 587]]], dtype=int32),
#  array([[[684, 586]],
#
#         [[684, 587]],
#
#         [[684, 588]],
#
#         [[684, 589]],
#
#         [[685, 589]],
#
#         [[686, 589]],
#
#         [[687, 589]],
#
#         [[687, 588]],
#
#         [[686, 587]],
#
#         [[686, 586]],
#
#         [[685, 586]]], dtype=int32),
#  array([[[701, 585]]], dtype=int32),
#  array([[[695, 585]]], dtype=int32),
#  array([[[442, 585]],
#
#         [[443, 585]],
#
#         [[444, 585]],
#
#         [[443, 585]]], dtype=int32),
#  array([[[550, 584]]], dtype=int32),
#  array([[[358, 583]],
#
#         [[358, 584]]], dtype=int32),
#  array([[[370, 580]],
#
#         [[371, 580]]], dtype=int32),
#  array([[[694, 578]],
#
#         [[695, 579]],
#
#         [[695, 578]]], dtype=int32),
#  array([[[448, 578]]], dtype=int32),
#  array([[[691, 577]],
#
#         [[692, 577]]], dtype=int32),
#  array([[[687, 577]],
#
#         [[688, 578]]], dtype=int32),
#  array([[[683, 574]],
#
#         [[682, 575]],
#
#         [[681, 576]],
#
#         [[680, 575]],
#
#         [[679, 576]],
#
#         [[678, 576]],
#
#         [[677, 576]],
#
#         [[676, 577]],
#
#         [[676, 578]],
#
#         [[675, 579]],
#
#         [[674, 579]],
#
#         [[673, 579]],
#
#         [[672, 579]],
#
#         [[671, 579]],
#
#         [[670, 579]],
#
#         [[669, 579]],
#
#         [[669, 580]],
#
#         [[670, 581]],
#
#         [[671, 581]],
#
#         [[672, 581]],
#
#         [[673, 581]],
#
#         [[674, 581]],
#
#         [[675, 580]],
#
#         [[676, 580]],
#
#         [[677, 580]],
#
#         [[678, 580]],
#
#         [[679, 580]],
#
#         [[679, 579]],
#
#         [[679, 578]],
#
#         [[680, 577]],
#
#         [[681, 577]],
#
#         [[682, 577]],
#
#         [[683, 578]],
#
#         [[683, 579]],
#
#         [[684, 579]],
#
#         [[684, 578]],
#
#         [[684, 577]],
#
#         [[684, 576]],
#
#         [[684, 575]],
#
#         [[684, 574]]], dtype=int32),
#  array([[[571, 573]],
#
#         [[570, 574]],
#
#         [[570, 575]],
#
#         [[570, 576]],
#
#         [[570, 577]],
#
#         [[571, 577]],
#
#         [[572, 578]],
#
#         [[573, 578]],
#
#         [[574, 578]],
#
#         [[575, 579]],
#
#         [[576, 578]],
#
#         [[577, 578]],
#
#         [[578, 578]],
#
#         [[579, 577]],
#
#         [[579, 576]],
#
#         [[580, 575]],
#
#         [[580, 574]],
#
#         [[579, 574]],
#
#         [[578, 574]],
#
#         [[577, 574]],
#
#         [[576, 574]],
#
#         [[575, 574]],
#
#         [[574, 573]],
#
#         [[573, 573]],
#
#         [[572, 573]]], dtype=int32),
#  array([[[640, 569]]], dtype=int32),
#  array([[[544, 568]]], dtype=int32),
#  array([[[540, 567]],
#
#         [[541, 567]],
#
#         [[542, 567]],
#
#         [[541, 567]]], dtype=int32),
#  array([[[376, 566]],
#
#         [[376, 567]]], dtype=int32),
#  array([[[648, 565]],
#
#         [[647, 566]],
#
#         [[646, 566]],
#
#         [[645, 566]],
#
#         [[645, 567]],
#
#         [[646, 567]],
#
#         [[647, 567]],
#
#         [[648, 566]],
#
#         [[649, 565]]], dtype=int32),
#  array([[[440, 564]],
#
#         [[440, 565]]], dtype=int32),
#  array([[[539, 563]],
#
#         [[538, 564]],
#
#         [[537, 564]],
#
#         [[536, 564]],
#
#         [[537, 564]],
#
#         [[538, 564]],
#
#         [[539, 564]],
#
#         [[540, 564]],
#
#         [[541, 564]],
#
#         [[542, 564]],
#
#         [[542, 563]],
#
#         [[541, 563]],
#
#         [[540, 563]]], dtype=int32),
#  array([[[518, 563]],
#
#         [[518, 564]],
#
#         [[519, 564]],
#
#         [[519, 563]]], dtype=int32),
#  array([[[568, 562]],
#
#         [[568, 563]],
#
#         [[569, 563]],
#
#         [[570, 563]],
#
#         [[571, 563]],
#
#         [[571, 562]],
#
#         [[570, 562]],
#
#         [[569, 562]]], dtype=int32),
#  array([[[431, 562]],
#
#         [[432, 563]],
#
#         [[432, 564]],
#
#         [[432, 565]],
#
#         [[433, 565]],
#
#         [[434, 564]],
#
#         [[433, 563]],
#
#         [[433, 562]],
#
#         [[432, 562]]], dtype=int32),
#  array([[[459, 561]],
#
#         [[460, 561]],
#
#         [[461, 562]],
#
#         [[460, 561]]], dtype=int32),
#  array([[[344, 561]],
#
#         [[345, 561]]], dtype=int32),
#  array([[[445, 560]],
#
#         [[445, 561]],
#
#         [[446, 561]],
#
#         [[447, 560]],
#
#         [[446, 560]]], dtype=int32),
#  array([[[451, 558]],
#
#         [[451, 559]],
#
#         [[452, 560]],
#
#         [[452, 561]],
#
#         [[453, 561]],
#
#         [[454, 561]],
#
#         [[454, 560]],
#
#         [[453, 559]],
#
#         [[452, 559]]], dtype=int32),
#  array([[[520, 557]],
#
#         [[520, 558]]], dtype=int32),
#  array([[[456, 557]],
#
#         [[456, 558]],
#
#         [[456, 559]],
#
#         [[456, 558]]], dtype=int32),
#  array([[[361, 557]]], dtype=int32),
#  array([[[352, 557]]], dtype=int32),
#  array([[[648, 556]],
#
#         [[647, 557]],
#
#         [[646, 557]],
#
#         [[647, 557]],
#
#         [[648, 557]]], dtype=int32),
#  array([[[643, 554]],
#
#         [[644, 555]],
#
#         [[645, 554]],
#
#         [[646, 554]],
#
#         [[645, 554]],
#
#         [[644, 554]]], dtype=int32),
#  array([[[527, 554]],
#
#         [[528, 554]],
#
#         [[529, 554]],
#
#         [[530, 554]],
#
#         [[529, 554]],
#
#         [[528, 554]]], dtype=int32),
#  array([[[520, 554]],
#
#         [[520, 555]],
#
#         [[521, 555]],
#
#         [[522, 554]],
#
#         [[521, 554]]], dtype=int32),
#  array([[[442, 553]],
#
#         [[443, 553]],
#
#         [[444, 554]],
#
#         [[445, 554]],
#
#         [[445, 553]],
#
#         [[444, 553]],
#
#         [[443, 553]]], dtype=int32),
#  array([[[435, 553]],
#
#         [[436, 553]]], dtype=int32),
#  array([[[431, 553]]], dtype=int32),
#  array([[[686, 552]],
#
#         [[686, 553]],
#
#         [[687, 553]],
#
#         [[688, 553]],
#
#         [[687, 552]]], dtype=int32),
#  array([[[349, 552]],
#
#         [[349, 553]]], dtype=int32),
#  array([[[343, 552]]], dtype=int32),
#  array([[[348, 549]],
#
#         [[348, 550]],
#
#         [[349, 549]]], dtype=int32),
#  array([[[344, 549]]], dtype=int32),
#  array([[[341, 548]],
#
#         [[341, 549]],
#
#         [[342, 549]]], dtype=int32),
#  array([[[584, 547]],
#
#         [[584, 548]],
#
#         [[585, 548]],
#
#         [[586, 548]],
#
#         [[587, 548]],
#
#         [[586, 548]],
#
#         [[585, 547]]], dtype=int32),
#  array([[[364, 547]]], dtype=int32),
#  array([[[352, 547]]], dtype=int32),
#  array([[[753, 546]],
#
#         [[754, 546]]], dtype=int32),
#  array([[[689, 546]],
#
#         [[690, 547]],
#
#         [[691, 547]],
#
#         [[692, 548]],
#
#         [[693, 547]],
#
#         [[693, 546]],
#
#         [[692, 546]],
#
#         [[691, 546]],
#
#         [[690, 546]]], dtype=int32),
#  array([[[681, 545]],
#
#         [[681, 546]],
#
#         [[681, 547]],
#
#         [[682, 546]],
#
#         [[682, 545]]], dtype=int32),
#  array([[[691, 543]],
#
#         [[690, 544]],
#
#         [[691, 544]],
#
#         [[692, 543]]], dtype=int32),
#  array([[[687, 543]],
#
#         [[687, 544]],
#
#         [[687, 545]],
#
#         [[687, 546]],
#
#         [[687, 547]],
#
#         [[687, 548]],
#
#         [[687, 549]],
#
#         [[688, 549]],
#
#         [[689, 550]],
#
#         [[688, 549]],
#
#         [[687, 548]],
#
#         [[687, 547]],
#
#         [[687, 546]],
#
#         [[687, 545]],
#
#         [[687, 544]]], dtype=int32),
#  array([[[696, 542]]], dtype=int32),
#  array([[[424, 542]]], dtype=int32),
#  array([[[341, 541]],
#
#         [[341, 542]],
#
#         [[341, 543]],
#
#         [[341, 544]],
#
#         [[341, 545]],
#
#         [[342, 546]],
#
#         [[343, 546]],
#
#         [[344, 546]],
#
#         [[345, 546]],
#
#         [[345, 545]],
#
#         [[344, 545]],
#
#         [[343, 544]],
#
#         [[342, 543]],
#
#         [[342, 542]]], dtype=int32),
#  array([[[637, 540]],
#
#         [[637, 541]],
#
#         [[637, 542]],
#
#         [[638, 542]],
#
#         [[639, 542]],
#
#         [[640, 542]],
#
#         [[641, 541]],
#
#         [[640, 540]],
#
#         [[639, 540]],
#
#         [[638, 540]]], dtype=int32),
#  array([[[586, 540]],
#
#         [[585, 541]],
#
#         [[584, 541]],
#
#         [[585, 541]],
#
#         [[586, 541]],
#
#         [[587, 541]],
#
#         [[588, 541]],
#
#         [[588, 540]],
#
#         [[587, 540]]], dtype=int32),
#  array([[[667, 538]],
#
#         [[667, 539]],
#
#         [[667, 540]],
#
#         [[667, 541]],
#
#         [[668, 540]],
#
#         [[669, 541]],
#
#         [[669, 542]],
#
#         [[669, 543]],
#
#         [[669, 544]],
#
#         [[670, 545]],
#
#         [[669, 546]],
#
#         [[668, 546]],
#
#         [[667, 545]],
#
#         [[667, 544]],
#
#         [[666, 545]],
#
#         [[666, 546]],
#
#         [[665, 547]],
#
#         [[664, 548]],
#
#         [[663, 548]],
#
#         [[662, 547]],
#
#         [[661, 546]],
#
#         [[660, 545]],
#
#         [[659, 544]],
#
#         [[658, 544]],
#
#         [[657, 543]],
#
#         [[657, 542]],
#
#         [[656, 541]],
#
#         [[655, 541]],
#
#         [[654, 540]],
#
#         [[653, 540]],
#
#         [[652, 540]],
#
#         [[651, 540]],
#
#         [[650, 540]],
#
#         [[649, 541]],
#
#         [[649, 542]],
#
#         [[649, 543]],
#
#         [[649, 544]],
#
#         [[648, 545]],
#
#         [[647, 544]],
#
#         [[646, 544]],
#
#         [[645, 544]],
#
#         [[644, 544]],
#
#         [[644, 545]],
#
#         [[645, 545]],
#
#         [[646, 546]],
#
#         [[647, 546]],
#
#         [[648, 547]],
#
#         [[648, 548]],
#
#         [[649, 548]],
#
#         [[650, 548]],
#
#         [[651, 548]],
#
#         [[652, 549]],
#
#         [[652, 550]],
#
#         [[653, 551]],
#
#         [[654, 552]],
#
#         [[653, 553]],
#
#         [[652, 553]],
#
#         [[651, 553]],
#
#         [[650, 552]],
#
#         [[650, 551]],
#
#         [[650, 550]],
#
#         [[649, 551]],
#
#         [[650, 552]],
#
#         [[649, 553]],
#
#         [[650, 553]],
#
#         [[651, 554]],
#
#         [[651, 555]],
#
#         [[652, 555]],
#
#         [[653, 556]],
#
#         [[654, 556]],
#
#         [[655, 556]],
#
#         [[656, 557]],
#
#         [[655, 558]],
#
#         [[654, 559]],
#
#         [[653, 559]],
#
#         [[653, 560]],
#
#         [[654, 559]],
#
#         [[655, 560]],
#
#         [[656, 561]],
#
#         [[657, 561]],
#
#         [[658, 561]],
#
#         [[659, 561]],
#
#         [[660, 562]],
#
#         [[659, 563]],
#
#         [[659, 564]],
#
#         [[658, 565]],
#
#         [[657, 565]],
#
#         [[656, 564]],
#
#         [[655, 564]],
#
#         [[654, 564]],
#
#         [[653, 565]],
#
#         [[654, 566]],
#
#         [[654, 567]],
#
#         [[653, 568]],
#
#         [[652, 569]],
#
#         [[651, 569]],
#
#         [[650, 569]],
#
#         [[649, 569]],
#
#         [[648, 569]],
#
#         [[648, 570]],
#
#         [[649, 570]],
#
#         [[650, 570]],
#
#         [[651, 570]],
#
#         [[652, 569]],
#
#         [[653, 570]],
#
#         [[654, 571]],
#
#         [[654, 572]],
#
#         [[653, 573]],
#
#         [[652, 573]],
#
#         [[651, 573]],
#
#         [[650, 573]],
#
#         [[649, 574]],
#
#         [[648, 574]],
#
#         [[649, 574]],
#
#         [[650, 574]],
#
#         [[651, 574]],
#
#         [[652, 575]],
#
#         [[652, 576]],
#
#         [[651, 577]],
#
#         [[652, 577]],
#
#         [[653, 577]],
#
#         [[653, 576]],
#
#         [[652, 575]],
#
#         [[653, 574]],
#
#         [[654, 573]],
#
#         [[655, 572]],
#
#         [[656, 572]],
#
#         [[657, 572]],
#
#         [[658, 573]],
#
#         [[658, 574]],
#
#         [[659, 575]],
#
#         [[658, 576]],
#
#         [[658, 577]],
#
#         [[659, 577]],
#
#         [[660, 577]],
#
#         [[661, 578]],
#
#         [[662, 578]],
#
#         [[663, 578]],
#
#         [[664, 579]],
#
#         [[664, 580]],
#
#         [[664, 581]],
#
#         [[665, 580]],
#
#         [[666, 579]],
#
#         [[666, 578]],
#
#         [[667, 577]],
#
#         [[668, 577]],
#
#         [[669, 577]],
#
#         [[670, 577]],
#
#         [[671, 577]],
#
#         [[671, 576]],
#
#         [[670, 575]],
#
#         [[669, 574]],
#
#         [[668, 574]],
#
#         [[667, 575]],
#
#         [[666, 576]],
#
#         [[665, 576]],
#
#         [[664, 576]],
#
#         [[663, 575]],
#
#         [[663, 574]],
#
#         [[663, 573]],
#
#         [[664, 572]],
#
#         [[665, 572]],
#
#         [[666, 572]],
#
#         [[667, 572]],
#
#         [[668, 572]],
#
#         [[669, 572]],
#
#         [[670, 571]],
#
#         [[671, 571]],
#
#         [[672, 571]],
#
#         [[673, 571]],
#
#         [[674, 572]],
#
#         [[674, 573]],
#
#         [[675, 574]],
#
#         [[676, 574]],
#
#         [[677, 574]],
#
#         [[678, 574]],
#
#         [[679, 573]],
#
#         [[679, 572]],
#
#         [[679, 571]],
#
#         [[679, 570]],
#
#         [[679, 569]],
#
#         [[680, 568]],
#
#         [[681, 568]],
#
#         [[682, 569]],
#
#         [[683, 569]],
#
#         [[684, 570]],
#
#         [[685, 571]],
#
#         [[686, 571]],
#
#         [[687, 571]],
#
#         [[688, 572]],
#
#         [[688, 573]],
#
#         [[688, 572]],
#
#         [[689, 571]],
#
#         [[690, 571]],
#
#         [[691, 571]],
#
#         [[692, 572]],
#
#         [[692, 573]],
#
#         [[692, 572]],
#
#         [[692, 571]],
#
#         [[692, 570]],
#
#         [[693, 569]],
#
#         [[693, 568]],
#
#         [[692, 567]],
#
#         [[692, 566]],
#
#         [[693, 565]],
#
#         [[692, 564]],
#
#         [[691, 563]],
#
#         [[691, 562]],
#
#         [[691, 561]],
#
#         [[692, 560]],
#
#         [[693, 559]],
#
#         [[693, 558]],
#
#         [[692, 557]],
#
#         [[692, 556]],
#
#         [[692, 555]],
#
#         [[693, 554]],
#
#         [[692, 554]],
#
#         [[691, 553]],
#
#         [[691, 554]],
#
#         [[691, 555]],
#
#         [[690, 556]],
#
#         [[689, 557]],
#
#         [[688, 557]],
#
#         [[687, 557]],
#
#         [[686, 558]],
#
#         [[686, 559]],
#
#         [[687, 560]],
#
#         [[686, 561]],
#
#         [[687, 561]],
#
#         [[688, 562]],
#
#         [[689, 562]],
#
#         [[690, 562]],
#
#         [[691, 563]],
#
#         [[690, 564]],
#
#         [[689, 565]],
#
#         [[688, 566]],
#
#         [[687, 566]],
#
#         [[686, 566]],
#
#         [[685, 565]],
#
#         [[684, 565]],
#
#         [[683, 565]],
#
#         [[682, 565]],
#
#         [[681, 565]],
#
#         [[680, 566]],
#
#         [[679, 566]],
#
#         [[678, 566]],
#
#         [[677, 566]],
#
#         [[676, 565]],
#
#         [[675, 566]],
#
#         [[674, 566]],
#
#         [[673, 565]],
#
#         [[674, 564]],
#
#         [[675, 563]],
#
#         [[676, 563]],
#
#         [[677, 563]],
#
#         [[678, 562]],
#
#         [[679, 562]],
#
#         [[679, 561]],
#
#         [[678, 560]],
#
#         [[679, 559]],
#
#         [[679, 558]],
#
#         [[680, 557]],
#
#         [[680, 556]],
#
#         [[679, 555]],
#
#         [[678, 555]],
#
#         [[679, 556]],
#
#         [[679, 557]],
#
#         [[678, 558]],
#
#         [[677, 558]],
#
#         [[676, 558]],
#
#         [[675, 557]],
#
#         [[674, 556]],
#
#         [[674, 555]],
#
#         [[674, 554]],
#
#         [[673, 554]],
#
#         [[672, 553]],
#
#         [[673, 552]],
#
#         [[674, 552]],
#
#         [[675, 552]],
#
#         [[675, 551]],
#
#         [[676, 550]],
#
#         [[676, 549]],
#
#         [[676, 548]],
#
#         [[677, 547]],
#
#         [[678, 546]],
#
#         [[677, 545]],
#
#         [[677, 544]],
#
#         [[677, 543]],
#
#         [[676, 542]],
#
#         [[675, 543]],
#
#         [[675, 544]],
#
#         [[675, 545]],
#
#         [[674, 546]],
#
#         [[673, 545]],
#
#         [[673, 544]],
#
#         [[672, 543]],
#
#         [[672, 542]],
#
#         [[671, 543]],
#
#         [[670, 542]],
#
#         [[670, 541]],
#
#         [[670, 540]],
#
#         [[670, 539]],
#
#         [[669, 539]],
#
#         [[668, 539]]], dtype=int32),
#  array([[[664, 577]],
#
#         [[665, 576]],
#
#         [[666, 576]],
#
#         [[667, 577]],
#
#         [[666, 578]],
#
#         [[665, 578]]], dtype=int32),
#  array([[[663, 571]],
#
#         [[664, 570]],
#
#         [[665, 571]],
#
#         [[664, 572]]], dtype=int32),
#  array([[[666, 570]],
#
#         [[667, 569]],
#
#         [[668, 569]],
#
#         [[669, 570]],
#
#         [[668, 571]],
#
#         [[667, 571]]], dtype=int32),
#  array([[[663, 569]],
#
#         [[664, 568]],
#
#         [[665, 569]],
#
#         [[664, 570]]], dtype=int32),
#  array([[[660, 561]],
#
#         [[661, 560]],
#
#         [[662, 560]],
#
#         [[663, 560]],
#
#         [[664, 560]],
#
#         [[665, 560]],
#
#         [[666, 561]],
#
#         [[666, 562]],
#
#         [[665, 563]],
#
#         [[664, 564]],
#
#         [[663, 563]],
#
#         [[662, 562]],
#
#         [[661, 562]]], dtype=int32),
#  array([[[674, 560]],
#
#         [[675, 559]],
#
#         [[676, 560]],
#
#         [[675, 561]]], dtype=int32),
#  array([[[671, 560]],
#
#         [[672, 559]],
#
#         [[673, 560]],
#
#         [[673, 561]],
#
#         [[674, 561]],
#
#         [[675, 562]],
#
#         [[674, 563]],
#
#         [[673, 563]],
#
#         [[672, 563]],
#
#         [[671, 562]],
#
#         [[671, 561]]], dtype=int32),
#  array([[[687, 559]],
#
#         [[688, 558]],
#
#         [[689, 558]],
#
#         [[690, 559]],
#
#         [[689, 560]],
#
#         [[688, 561]],
#
#         [[687, 560]]], dtype=int32),
#  array([[[658, 555]],
#
#         [[659, 554]],
#
#         [[660, 555]],
#
#         [[660, 556]],
#
#         [[660, 557]],
#
#         [[659, 558]],
#
#         [[658, 559]],
#
#         [[657, 558]],
#
#         [[656, 557]],
#
#         [[657, 556]]], dtype=int32),
#  array([[[662, 554]],
#
#         [[663, 553]],
#
#         [[664, 553]],
#
#         [[665, 554]],
#
#         [[665, 555]],
#
#         [[666, 556]],
#
#         [[667, 556]],
#
#         [[668, 557]],
#
#         [[668, 558]],
#
#         [[667, 559]],
#
#         [[666, 559]],
#
#         [[665, 558]],
#
#         [[664, 557]],
#
#         [[663, 557]],
#
#         [[662, 556]],
#
#         [[661, 555]]], dtype=int32),
#  array([[[668, 550]],
#
#         [[669, 549]],
#
#         [[670, 550]],
#
#         [[671, 551]],
#
#         [[671, 552]],
#
#         [[671, 553]],
#
#         [[670, 554]],
#
#         [[669, 553]],
#
#         [[668, 552]],
#
#         [[668, 551]]], dtype=int32),
#  array([[[667, 549]],
#
#         [[668, 548]],
#
#         [[669, 549]],
#
#         [[668, 550]]], dtype=int32),
#  array([[[666, 548]],
#
#         [[667, 547]],
#
#         [[668, 548]],
#
#         [[667, 549]]], dtype=int32),
#  array([[[670, 547]],
#
#         [[671, 546]],
#
#         [[672, 547]],
#
#         [[673, 548]],
#
#         [[672, 549]],
#
#         [[671, 549]],
#
#         [[670, 548]]], dtype=int32),
#  array([[[669, 537]],
#
#         [[670, 537]],
#
#         [[671, 537]],
#
#         [[670, 537]]], dtype=int32),
#  array([[[678, 536]],
#
#         [[677, 537]],
#
#         [[677, 538]],
#
#         [[678, 538]],
#
#         [[679, 538]],
#
#         [[680, 539]],
#
#         [[681, 540]],
#
#         [[682, 539]],
#
#         [[682, 538]],
#
#         [[682, 537]],
#
#         [[681, 536]],
#
#         [[680, 536]],
#
#         [[679, 536]]], dtype=int32),
#  array([[[697, 535]],
#
#         [[696, 536]],
#
#         [[696, 537]],
#
#         [[697, 537]],
#
#         [[698, 536]],
#
#         [[698, 535]]], dtype=int32),
#  array([[[687, 534]],
#
#         [[687, 535]],
#
#         [[687, 536]],
#
#         [[687, 537]],
#
#         [[686, 538]],
#
#         [[686, 539]],
#
#         [[686, 540]],
#
#         [[687, 541]],
#
#         [[687, 540]],
#
#         [[687, 539]],
#
#         [[687, 538]],
#
#         [[687, 537]],
#
#         [[687, 536]],
#
#         [[688, 535]],
#
#         [[689, 535]],
#
#         [[690, 535]],
#
#         [[691, 536]],
#
#         [[690, 537]],
#
#         [[689, 538]],
#
#         [[690, 539]],
#
#         [[690, 540]],
#
#         [[690, 541]],
#
#         [[691, 541]],
#
#         [[692, 541]],
#
#         [[692, 540]],
#
#         [[692, 539]],
#
#         [[693, 538]],
#
#         [[693, 537]],
#
#         [[693, 536]],
#
#         [[692, 536]],
#
#         [[691, 536]],
#
#         [[690, 535]],
#
#         [[689, 534]],
#
#         [[688, 534]]], dtype=int32),
#  array([[[610, 534]]], dtype=int32),
#  array([[[572, 533]],
#
#         [[572, 534]],
#
#         [[573, 534]],
#
#         [[574, 535]],
#
#         [[575, 535]],
#
#         [[576, 536]],
#
#         [[577, 536]],
#
#         [[578, 537]],
#
#         [[579, 537]],
#
#         [[580, 537]],
#
#         [[581, 537]],
#
#         [[582, 537]],
#
#         [[583, 536]],
#
#         [[584, 536]],
#
#         [[584, 535]],
#
#         [[583, 534]],
#
#         [[582, 534]],
#
#         [[581, 533]],
#
#         [[580, 533]],
#
#         [[579, 533]],
#
#         [[578, 533]],
#
#         [[577, 533]],
#
#         [[576, 533]],
#
#         [[575, 533]],
#
#         [[574, 533]],
#
#         [[573, 533]]], dtype=int32),
#  array([[[681, 531]],
#
#         [[680, 532]],
#
#         [[679, 532]],
#
#         [[680, 532]],
#
#         [[681, 533]],
#
#         [[682, 532]]], dtype=int32),
#  array([[[690, 530]],
#
#         [[689, 531]],
#
#         [[688, 532]],
#
#         [[689, 532]],
#
#         [[690, 531]]], dtype=int32),
#  array([[[625, 530]],
#
#         [[624, 531]],
#
#         [[624, 532]],
#
#         [[625, 533]],
#
#         [[626, 533]],
#
#         [[627, 534]],
#
#         [[627, 533]],
#
#         [[627, 532]],
#
#         [[627, 531]],
#
#         [[626, 530]]], dtype=int32),
#  array([[[608, 530]],
#
#         [[609, 530]]], dtype=int32),
#  array([[[423, 530]],
#
#         [[423, 531]]], dtype=int32),
#  array([[[630, 529]],
#
#         [[631, 530]],
#
#         [[631, 531]],
#
#         [[632, 532]],
#
#         [[631, 533]],
#
#         [[631, 534]],
#
#         [[632, 533]],
#
#         [[633, 534]],
#
#         [[633, 535]],
#
#         [[632, 536]],
#
#         [[632, 537]],
#
#         [[632, 536]],
#
#         [[633, 535]],
#
#         [[634, 536]],
#
#         [[634, 537]],
#
#         [[634, 538]],
#
#         [[635, 538]],
#
#         [[636, 538]],
#
#         [[637, 538]],
#
#         [[637, 537]],
#
#         [[636, 536]],
#
#         [[636, 535]],
#
#         [[635, 534]],
#
#         [[635, 533]],
#
#         [[634, 532]],
#
#         [[633, 531]],
#
#         [[632, 531]],
#
#         [[631, 530]],
#
#         [[631, 529]]], dtype=int32),
#  array([[[620, 529]]], dtype=int32),
#  array([[[359, 528]],
#
#         [[360, 528]]], dtype=int32),
#  array([[[610, 526]],
#
#         [[609, 527]],
#
#         [[608, 527]],
#
#         [[608, 528]],
#
#         [[609, 527]],
#
#         [[610, 527]]], dtype=int32),
#  array([[[338, 525]],
#
#         [[338, 526]],
#
#         [[338, 527]],
#
#         [[338, 526]]], dtype=int32),
#  array([[[679, 524]],
#
#         [[679, 525]]], dtype=int32),
#  array([[[686, 521]],
#
#         [[687, 522]],
#
#         [[687, 523]],
#
#         [[688, 524]],
#
#         [[687, 525]],
#
#         [[687, 526]],
#
#         [[688, 527]],
#
#         [[689, 527]],
#
#         [[690, 526]],
#
#         [[691, 526]],
#
#         [[692, 527]],
#
#         [[693, 527]],
#
#         [[693, 526]],
#
#         [[692, 526]],
#
#         [[691, 525]],
#
#         [[690, 524]],
#
#         [[689, 524]],
#
#         [[688, 523]],
#
#         [[687, 522]]], dtype=int32),
#  array([[[681, 521]]], dtype=int32),
#  array([[[576, 521]],
#
#         [[575, 522]],
#
#         [[574, 522]],
#
#         [[575, 522]],
#
#         [[576, 523]],
#
#         [[577, 523]],
#
#         [[578, 523]],
#
#         [[579, 523]],
#
#         [[580, 523]],
#
#         [[580, 522]],
#
#         [[579, 522]],
#
#         [[578, 522]],
#
#         [[577, 521]]], dtype=int32),
#  array([[[566, 521]],
#
#         [[565, 522]],
#
#         [[564, 522]],
#
#         [[565, 523]],
#
#         [[566, 523]],
#
#         [[567, 523]],
#
#         [[568, 523]],
#
#         [[569, 522]],
#
#         [[568, 522]],
#
#         [[567, 521]]], dtype=int32),
#  array([[[338, 521]],
#
#         [[337, 522]],
#
#         [[338, 523]],
#
#         [[339, 523]],
#
#         [[339, 522]]], dtype=int32),
#  array([[[541, 518]],
#
# ...
#
#         [[354, 121]],
#
#         [[355, 122]],
#
#         [[354, 123]],
#
#         [[353, 123]]], dtype=int32),
#  array([[[316, 120]],
#
#         [[317, 119]],
#
#         [[318, 119]],
#
#         [[319, 119]],
#
#         [[320, 119]],
#
#         [[321, 119]],
#
#         [[322, 119]],
#
#         [[323, 120]],
#
#         [[323, 121]],
#
#         [[322, 122]],
#
#         [[321, 122]],
#
#         [[320, 122]],
#
#         [[319, 122]],
#
#         [[318, 122]],
#
#         [[317, 122]],
#
#         [[316, 121]]], dtype=int32),
#  array([[[321, 117]],
#
#         [[322, 116]],
#
#         [[323, 117]],
#
#         [[323, 118]],
#
#         [[322, 119]],
#
#         [[321, 118]]], dtype=int32),
#  array([[[320, 115]],
#
#         [[321, 114]],
#
#         [[322, 115]],
#
#         [[321, 116]]], dtype=int32),
#  array([[[311, 114]],
#
#         [[312, 113]],
#
#         [[313, 114]],
#
#         [[313, 115]],
#
#         [[313, 116]],
#
#         [[313, 117]],
#
#         [[312, 118]],
#
#         [[311, 117]],
#
#         [[311, 116]],
#
#         [[311, 115]]], dtype=int32),
#  array([[[313, 108]],
#
#         [[314, 107]],
#
#         [[315, 108]],
#
#         [[316, 109]],
#
#         [[315, 110]],
#
#         [[314, 110]],
#
#         [[313, 109]]], dtype=int32),
#  array([[[305,  97]],
#
#         [[306,  96]],
#
#         [[307,  96]],
#
#         [[308,  97]],
#
#         [[308,  98]],
#
#         [[307,  99]],
#
#         [[306,  98]]], dtype=int32),
#  array([[[302,  92]],
#
#         [[303,  91]],
#
#         [[304,  92]],
#
#         [[305,  93]],
#
#         [[304,  94]],
#
#         [[303,  94]],
#
#         [[302,  93]]], dtype=int32),
#  array([[[310,  90]],
#
#         [[311,  89]],
#
#         [[312,  90]],
#
#         [[311,  91]]], dtype=int32),
#  array([[[351,  79]],
#
#         [[352,  78]],
#
#         [[353,  79]],
#
#         [[354,  80]],
#
#         [[353,  81]],
#
#         [[352,  81]],
#
#         [[351,  80]]], dtype=int32),
#  array([[[307,  76]],
#
#         [[308,  75]],
#
#         [[309,  76]],
#
#         [[308,  77]]], dtype=int32),
#  array([[[313,  74]],
#
#         [[314,  73]],
#
#         [[315,  74]],
#
#         [[315,  75]],
#
#         [[315,  76]],
#
#         [[315,  77]],
#
#         [[315,  78]],
#
#         [[314,  79]],
#
#         [[314,  80]],
#
#         [[314,  81]],
#
#         [[313,  82]],
#
#         [[312,  81]],
#
#         [[312,  80]],
#
#         [[312,  79]],
#
#         [[312,  78]],
#
#         [[313,  77]],
#
#         [[313,  76]],
#
#         [[313,  75]]], dtype=int32),
#  array([[[123,  65]],
#
#         [[123,  66]]], dtype=int32),
#  array([[[447,  63]]], dtype=int32),
#  array([[[416,  63]],
#
#         [[415,  64]],
#
#         [[414,  64]],
#
#         [[413,  64]],
#
#         [[412,  64]],
#
#         [[411,  64]],
#
#         [[412,  64]],
#
#         [[413,  64]],
#
#         [[414,  64]],
#
#         [[415,  64]],
#
#         [[416,  65]],
#
#         [[415,  66]],
#
#         [[414,  66]],
#
#         [[413,  66]],
#
#         [[412,  66]],
#
#         [[411,  67]],
#
#         [[410,  68]],
#
#         [[409,  68]],
#
#         [[408,  67]],
#
#         [[408,  66]],
#
#         [[407,  67]],
#
#         [[406,  67]],
#
#         [[405,  67]],
#
#         [[404,  67]],
#
#         [[403,  67]],
#
#         [[402,  67]],
#
#         [[403,  67]],
#
#         [[404,  67]],
#
#         [[405,  67]],
#
#         [[406,  67]],
#
#         [[407,  67]],
#
#         [[408,  67]],
#
#         [[409,  68]],
#
#         [[409,  69]],
#
#         [[408,  70]],
#
#         [[407,  70]],
#
#         [[406,  70]],
#
#         [[405,  70]],
#
#         [[404,  70]],
#
#         [[403,  70]],
#
#         [[402,  70]],
#
#         [[401,  70]],
#
#         [[400,  70]],
#
#         [[401,  71]],
#
#         [[402,  71]],
#
#         [[403,  71]],
#
#         [[404,  71]],
#
#         [[405,  71]],
#
#         [[406,  71]],
#
#         [[407,  71]],
#
#         [[408,  72]],
#
#         [[407,  73]],
#
#         [[406,  73]],
#
#         [[405,  73]],
#
#         [[406,  73]],
#
#         [[407,  73]],
#
#         [[408,  74]],
#
#         [[407,  73]],
#
#         [[408,  72]],
#
#         [[409,  72]],
#
#         [[410,  73]],
#
#         [[409,  72]],
#
#         [[409,  71]],
#
#         [[410,  70]],
#
#         [[411,  70]],
#
#         [[412,  69]],
#
#         [[413,  69]],
#
#         [[414,  70]],
#
#         [[415,  70]],
#
#         [[416,  69]],
#
#         [[417,  70]],
#
#         [[418,  70]],
#
#         [[419,  70]],
#
#         [[420,  70]],
#
#         [[421,  70]],
#
#         [[422,  70]],
#
#         [[422,  69]],
#
#         [[423,  68]],
#
#         [[424,  67]],
#
#         [[425,  67]],
#
#         [[426,  68]],
#
#         [[427,  68]],
#
#         [[428,  68]],
#
#         [[429,  67]],
#
#         [[430,  67]],
#
#         [[430,  66]],
#
#         [[431,  65]],
#
#         [[432,  65]],
#
#         [[431,  65]],
#
#         [[430,  65]],
#
#         [[429,  65]],
#
#         [[428,  65]],
#
#         [[427,  65]],
#
#         [[426,  65]],
#
#         [[425,  64]],
#
#         [[424,  64]],
#
#         [[423,  64]],
#
#         [[422,  63]],
#
#         [[421,  63]],
#
#         [[420,  63]],
#
#         [[419,  63]],
#
#         [[418,  64]],
#
#         [[417,  64]]], dtype=int32),
#  array([[[418,  67]],
#
#         [[419,  66]],
#
#         [[420,  66]],
#
#         [[421,  66]],
#
#         [[422,  67]],
#
#         [[422,  68]],
#
#         [[421,  69]],
#
#         [[420,  69]],
#
#         [[419,  68]]], dtype=int32),
#  array([[[415,  66]],
#
#         [[416,  65]],
#
#         [[417,  65]],
#
#         [[418,  66]],
#
#         [[417,  67]],
#
#         [[416,  67]]], dtype=int32),
#  array([[[419,  65]],
#
#         [[420,  64]],
#
#         [[421,  64]],
#
#         [[422,  65]],
#
#         [[421,  66]],
#
#         [[420,  66]]], dtype=int32),
#  array([[[440,  62]],
#
#         [[441,  62]]], dtype=int32),
#  array([[[90, 62]],
#
#         [[91, 62]]], dtype=int32),
#  array([[[480,  60]],
#
#         [[480,  61]],
#
#         [[481,  61]],
#
#         [[482,  62]],
#
#         [[481,  63]],
#
#         [[480,  63]],
#
#         [[480,  64]],
#
#         [[481,  64]],
#
#         [[482,  64]],
#
#         [[483,  65]],
#
#         [[484,  65]],
#
#         [[485,  65]],
#
#         [[486,  66]],
#
#         [[487,  67]],
#
#         [[487,  68]],
#
#         [[487,  69]],
#
#         [[487,  70]],
#
#         [[487,  71]],
#
#         [[486,  72]],
#
#         [[486,  73]],
#
#         [[486,  74]],
#
#         [[486,  75]],
#
#         [[486,  76]],
#
#         [[485,  77]],
#
#         [[484,  77]],
#
#         [[483,  77]],
#
#         [[482,  76]],
#
#         [[482,  75]],
#
#         [[483,  74]],
#
#         [[482,  73]],
#
#         [[482,  72]],
#
#         [[482,  71]],
#
#         [[482,  70]],
#
#         [[481,  69]],
#
#         [[480,  69]],
#
#         [[479,  69]],
#
#         [[478,  69]],
#
#         [[477,  68]],
#
#         [[476,  67]],
#
#         [[475,  67]],
#
#         [[476,  68]],
#
#         [[477,  69]],
#
#         [[477,  70]],
#
#         [[476,  71]],
#
#         [[475,  72]],
#
#         [[474,  72]],
#
#         [[473,  72]],
#
#         [[472,  72]],
#
#         [[471,  71]],
#
#         [[470,  70]],
#
#         [[470,  69]],
#
#         [[471,  68]],
#
#         [[472,  67]],
#
#         [[473,  66]],
#
#         [[472,  66]],
#
#         [[471,  66]],
#
#         [[470,  66]],
#
#         [[469,  65]],
#
#         [[469,  64]],
#
#         [[468,  63]],
#
#         [[468,  62]],
#
#         [[468,  63]],
#
#         [[468,  64]],
#
#         [[468,  65]],
#
#         [[467,  66]],
#
#         [[466,  66]],
#
#         [[465,  66]],
#
#         [[464,  66]],
#
#         [[465,  67]],
#
#         [[464,  68]],
#
#         [[464,  69]],
#
#         [[463,  70]],
#
#         [[462,  71]],
#
#         [[461,  71]],
#
#         [[460,  71]],
#
#         [[461,  71]],
#
#         [[462,  71]],
#
#         [[463,  70]],
#
#         [[464,  71]],
#
#         [[465,  71]],
#
#         [[466,  72]],
#
#         [[467,  73]],
#
#         [[468,  73]],
#
#         [[469,  72]],
#
#         [[470,  73]],
#
#         [[471,  73]],
#
#         [[472,  74]],
#
#         [[472,  75]],
#
#         [[473,  75]],
#
#         [[474,  76]],
#
#         [[475,  76]],
#
#         [[476,  76]],
#
#         [[477,  77]],
#
#         [[478,  77]],
#
#         [[479,  77]],
#
#         [[480,  78]],
#
#         [[481,  78]],
#
#         [[482,  78]],
#
#         [[483,  79]],
#
#         [[484,  80]],
#
#         [[484,  81]],
#
#         [[485,  81]],
#
#         [[486,  82]],
#
#         [[485,  81]],
#
#         [[486,  80]],
#
#         [[487,  79]],
#
#         [[487,  78]],
#
#         [[487,  77]],
#
#         [[487,  76]],
#
#         [[487,  75]],
#
#         [[487,  74]],
#
#         [[487,  73]],
#
#         [[487,  72]],
#
#         [[487,  71]],
#
#         [[487,  70]],
#
#         [[487,  69]],
#
#         [[487,  68]],
#
#         [[487,  67]],
#
#         [[488,  66]],
#
#         [[487,  65]],
#
#         [[488,  64]],
#
#         [[488,  63]],
#
#         [[487,  62]],
#
#         [[486,  62]],
#
#         [[485,  62]],
#
#         [[484,  61]],
#
#         [[483,  61]],
#
#         [[482,  60]],
#
#         [[481,  60]]], dtype=int32),
#  array([[[330,  60]],
#
#         [[331,  60]]], dtype=int32),
#  array([[[ 8, 60]],
#
#         [[ 8, 61]]], dtype=int32),
#  array([[[432,  59]],
#
#         [[433,  59]]], dtype=int32),
#  array([[[ 0, 59]],
#
#         [[ 0, 60]],
#
#         [[ 1, 59]]], dtype=int32),
#  array([[[15, 58]],
#
#         [[14, 59]],
#
#         [[13, 59]],
#
#         [[14, 60]],
#
#         [[15, 60]],
#
#         [[16, 61]],
#
#         [[15, 62]],
#
#         [[14, 62]],
#
#         [[15, 62]],
#
#         [[16, 62]],
#
#         [[17, 61]],
#
#         [[18, 61]],
#
#         [[17, 61]],
#
#         [[16, 61]],
#
#         [[15, 60]],
#
#         [[16, 59]]], dtype=int32),
#  array([[[520,  57]],
#
#         [[521,  58]],
#
#         [[522,  58]],
#
#         [[523,  58]],
#
#         [[524,  58]],
#
#         [[525,  58]],
#
#         [[524,  58]],
#
#         [[523,  58]],
#
#         [[522,  57]],
#
#         [[521,  57]]], dtype=int32),
#  array([[[420,  56]],
#
#         [[420,  57]],
#
#         [[421,  58]],
#
#         [[422,  58]],
#
#         [[423,  58]],
#
#         [[424,  59]],
#
#         [[425,  59]],
#
#         [[426,  60]],
#
#         [[427,  60]],
#
#         [[428,  60]],
#
#         [[429,  60]],
#
#         [[428,  60]],
#
#         [[427,  59]],
#
#         [[426,  58]],
#
#         [[425,  58]],
#
#         [[424,  58]],
#
#         [[423,  58]],
#
#         [[422,  57]],
#
#         [[421,  56]]], dtype=int32),
#  array([[[415,  56]],
#
#         [[416,  56]]], dtype=int32),
#  array([[[108,  56]],
#
#         [[107,  57]],
#
#         [[106,  57]],
#
#         [[105,  57]],
#
#         [[104,  57]],
#
#         [[105,  58]],
#
#         [[106,  59]],
#
#         [[107,  59]],
#
#         [[108,  59]],
#
#         [[109,  60]],
#
#         [[108,  61]],
#
#         [[107,  62]],
#
#         [[106,  63]],
#
#         [[105,  63]],
#
#         [[104,  62]],
#
#         [[104,  61]],
#
#         [[104,  62]],
#
#         [[105,  63]],
#
#         [[105,  64]],
#
#         [[106,  64]],
#
#         [[107,  63]],
#
#         [[108,  62]],
#
#         [[109,  61]],
#
#         [[110,  61]],
#
#         [[111,  61]],
#
#         [[112,  61]],
#
#         [[113,  60]],
#
#         [[114,  60]],
#
#         [[114,  59]],
#
#         [[113,  59]],
#
#         [[112,  58]],
#
#         [[111,  58]],
#
#         [[110,  58]],
#
#         [[109,  57]],
#
#         [[109,  56]]], dtype=int32),
#  array([[[105,  58]],
#
#         [[106,  57]],
#
#         [[107,  58]],
#
#         [[106,  59]]], dtype=int32),
#  array([[[482,  55]],
#
#         [[483,  55]]], dtype=int32),
#  array([[[479,  54]],
#
#         [[480,  54]]], dtype=int32),
#  array([[[108,  54]],
#
#         [[109,  54]]], dtype=int32),
#  array([[[441,  52]],
#
#         [[442,  52]],
#
#         [[443,  52]],
#
#         [[442,  52]]], dtype=int32),
#  array([[[471,  51]],
#
#         [[472,  51]],
#
#         [[473,  52]],
#
#         [[474,  52]],
#
#         [[475,  52]],
#
#         [[474,  52]],
#
#         [[473,  52]],
#
#         [[472,  51]]], dtype=int32),
#  array([[[439,  51]]], dtype=int32),
#  array([[[158,  51]],
#
#         [[157,  52]],
#
#         [[156,  53]],
#
#         [[155,  53]],
#
#         [[155,  54]],
#
#         [[155,  55]],
#
#         [[155,  56]],
#
#         [[154,  57]],
#
#         [[153,  57]],
#
#         [[154,  57]],
#
#         [[155,  56]],
#
#         [[156,  56]],
#
#         [[157,  56]],
#
#         [[158,  56]],
#
#         [[159,  55]],
#
#         [[158,  54]],
#
#         [[158,  53]],
#
#         [[158,  52]]], dtype=int32),
#  array([[[431,  50]],
#
#         [[432,  51]],
#
#         [[431,  52]],
#
#         [[432,  53]],
#
#         [[431,  54]],
#
#         [[430,  54]],
#
#         [[431,  54]],
#
#         [[432,  55]],
#
#         [[433,  55]],
#
#         [[434,  55]],
#
#         [[435,  55]],
#
#         [[436,  56]],
#
#         [[437,  57]],
#
#         [[437,  58]],
#
#         [[438,  58]],
#
#         [[439,  58]],
#
#         [[440,  59]],
#
#         [[439,  60]],
#
#         [[438,  60]],
#
#         [[439,  60]],
#
#         [[440,  59]],
#
#         [[441,  59]],
#
#         [[442,  59]],
#
#         [[443,  60]],
#
#         [[444,  60]],
#
#         [[445,  60]],
#
#         [[446,  60]],
#
#         [[447,  60]],
#
#         [[448,  61]],
#
#         [[449,  61]],
#
#         [[450,  61]],
#
#         [[451,  61]],
#
#         [[452,  61]],
#
#         [[453,  61]],
#
#         [[454,  61]],
#
#         [[455,  61]],
#
#         [[456,  62]],
#
#         [[457,  63]],
#
#         [[458,  63]],
#
#         [[459,  63]],
#
#         [[460,  63]],
#
#         [[461,  63]],
#
#         [[462,  64]],
#
#         [[463,  64]],
#
#         [[463,  63]],
#
#         [[463,  62]],
#
#         [[463,  61]],
#
#         [[463,  60]],
#
#         [[464,  59]],
#
#         [[464,  58]],
#
#         [[465,  57]],
#
#         [[466,  57]],
#
#         [[467,  57]],
#
#         [[468,  58]],
#
#         [[469,  57]],
#
#         [[470,  58]],
#
#         [[471,  58]],
#
#         [[472,  59]],
#
#         [[472,  60]],
#
#         [[473,  60]],
#
#         [[474,  60]],
#
#         [[474,  59]],
#
#         [[473,  58]],
#
#         [[473,  57]],
#
#         [[472,  57]],
#
#         [[471,  57]],
#
#         [[470,  56]],
#
#         [[471,  55]],
#
#         [[470,  55]],
#
#         [[469,  54]],
#
#         [[468,  54]],
#
#         [[467,  53]],
#
#         [[466,  53]],
#
#         [[465,  53]],
#
#         [[464,  53]],
#
#         [[463,  53]],
#
#         [[462,  53]],
#
#         [[461,  53]],
#
#         [[460,  54]],
#
#         [[459,  55]],
#
#         [[460,  55]],
#
#         [[461,  55]],
#
#         [[462,  55]],
#
#         [[463,  55]],
#
#         [[464,  56]],
#
#         [[465,  57]],
#
#         [[464,  58]],
#
#         [[464,  59]],
#
#         [[463,  60]],
#
#         [[462,  60]],
#
#         [[461,  60]],
#
#         [[460,  59]],
#
#         [[459,  58]],
#
#         [[458,  58]],
#
#         [[457,  58]],
#
#         [[456,  58]],
#
#         [[455,  57]],
#
#         [[454,  57]],
#
#         [[453,  56]],
#
#         [[452,  56]],
#
#         [[451,  56]],
#
#         [[450,  56]],
#
#         [[449,  56]],
#
#         [[448,  56]],
#
#         [[447,  55]],
#
#         [[446,  55]],
#
#         [[445,  55]],
#
#         [[444,  56]],
#
#         [[443,  55]],
#
#         [[442,  54]],
#
#         [[441,  55]],
#
#         [[440,  55]],
#
#         [[439,  56]],
#
#         [[438,  56]],
#
#         [[437,  55]],
#
#         [[436,  55]],
#
#         [[435,  54]],
#
#         [[434,  53]],
#
#         [[435,  52]],
#
#         [[436,  51]],
#
#         [[435,  51]],
#
#         [[434,  51]],
#
#         [[433,  51]],
#
#         [[432,  51]]], dtype=int32),
#  array([[[442,  57]],
#
#         [[443,  56]],
#
#         [[444,  57]],
#
#         [[443,  58]]], dtype=int32),
#  array([[[438,  57]],
#
#         [[439,  56]],
#
#         [[440,  57]],
#
#         [[439,  58]]], dtype=int32),
#  array([[[ 0, 50]]], dtype=int32),
#  array([[[412,  49]],
#
#         [[413,  49]]], dtype=int32),
#  array([[[410,  49]]], dtype=int32),
#  array([[[152,  48]]], dtype=int32),
#  array([[[108,  48]],
#
#         [[107,  49]],
#
#         [[106,  50]],
#
#         [[105,  51]],
#
#         [[105,  52]],
#
#         [[105,  53]],
#
#         [[104,  54]],
#
#         [[104,  55]],
#
#         [[104,  54]],
#
#         [[105,  53]],
#
#         [[106,  53]],
#
#         [[105,  52]],
#
#         [[106,  51]],
#
#         [[107,  50]],
#
#         [[108,  50]],
#
#         [[108,  49]]], dtype=int32),
#  array([[[343,  47]]], dtype=int32),
#  array([[[ 3, 46]],
#
#         [[ 4, 46]]], dtype=int32),
#  ...]
